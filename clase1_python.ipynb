# %% [markdown]
# <a href="https://colab.research.google.com/github/julian1416/taller-data-science/blob/rama1/clase1_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
with open('.gitignore', 'w') as f:
    f.write('.venv/\n')

# !pip install pandas
# !pip freeze > requirements.txt

print("¡Archivos .gitignore y requirements.txt creados con éxito!")
# Out:
# ...
# ¡Archivos .gitignore y requirements.txt creados con éxito!
