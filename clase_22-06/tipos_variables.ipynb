# %% [markdown]
# # Tipos en python
# # Variables
# # expresiones

# %% [markdown]
# * Enteros           -3 2 4 -5
# * punto flotante    3.2,  4.7
# * string            'hola mundo' "mi nombre"

# %%
type(3)
# Out:
# int

# %%
type(3.0)
# Out:
# float

# %%
type('hola mundo')
# Out:
# str

# %%
print('este es un tipo de dato booleano',type(False))
# Out:
# este es un tipo de dato booleano <class 'bool'>

# %%
type(3+5j)
# Out:
# complex

# %%
## F r e  
## 0 1 2 ..
name = "Fredy"

name[0]
# Out:
# 'F'

# %%
name[0]= 'B'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 name[0]= 'B'
#
# TypeError: 'str' object does not support item assignment

# %%
int(3.6)
# Out:
# 3

# %%
float(6)
# Out:
# 6.0

# %%
texto = '100'
type(texto)
# Out:
# str

# %%
int(texto)
# Out:
# 100

# %%
name = 'Johan'
int(name)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 2
#       1 name = 'Johan'
# ----> 2 int(name)
#
# ValueError: invalid literal for int() with base 10: 'Johan'

# %%
10 == 12
# Out:
# False

# %%
5 > 3
# Out:
# True

# %%
nombre = 'Fredy'
Edad = 35
estatura = 1.72
Hombre = True 

print('Nombre ',nombre, 'Edad ' , Edad )
print(f'Nombre {nombre } , Edad {Edad}')
# Out:
# Nombre  Fredy Edad  35
# Nombre Fredy , Edad 35

# %%
$nombre = 'Andres'
# Out:
#   Cell In[18], line 1
#     $nombre = 'Andres'
#     ^
# SyntaxError: invalid syntax

# %%
2nombre = 'carlos'
# Out:
#   Cell In[19], line 1
#     2nombre = 'carlos'
#     ^
# SyntaxError: invalid decimal literal

# %%
## no podemos usar palabras reservadas 
## if 
## while 
## for 
for = 35
# Out:
#   Cell In[20], line 5
#     for = 35
#         ^
# SyntaxError: invalid syntax

# %%
Valor_ = 350000
print(Valor_)
# Out:
# 350000

# %%
valor = 3
Valor = 5
print(valor, Valor)
# Out:
# 3 5

# %%
# precio de la casa 
# Prci =
Precio_de_la_casa = 5584854
print(Precio_de_la_casa)
# Out:
# 5584854

# %%
### Expresion 
## (-b +- (b^2 -4 a * c))/2a

# los operadores 
# suma +
# resta - 
# multiplicacion *
# potencia **
# division / 
# division //

# %%
b = 2
a = 1
c = 1

(-b + (-b**2 - 4*a*c)**0.5 )/(2*a)
# Out:
# (-0.9999999999999999+1.4142135623730951j)

# %%
## operadores booleano 
and 
or 
not

# %%
## igual igual == 
## menor igual <= 
## mayor igual >= 
## diferente =!
