# %% [markdown]
# <a id="quiz"></a>
# ## Cuestionario sobre Diccionarios

# %% [markdown]
# <b>Necesitarás este diccionario para las siguientes dos preguntas:</b>

# %%
# Diccionario de muestra para las preguntas

soundtrack_dic = {"The Bodyguard":"1992", "Saturday Night Fever":"1977"}
soundtrack_dic
# Out:
# {'The Bodyguard': '1992', 'Saturday Night Fever': '1977'}

# %% [markdown]
# a) En el diccionario <code>soundtrack_dic</code>, ¿cuáles son las llaves (keys)?

# %%
soundtrack_dic = {"The Bodyguard":"1992", "Saturday Night Fever":"1977"}

llaves = soundtrack_dic.keys()

print("Las llaves (keys) son:", llaves)
# Out:
# Las llaves (keys) son: dict_keys(['The Bodyguard', 'Saturday Night Fever'])

# %% [markdown]
# <details><summary>Haz clic aquí para ver la solución</summary>
#
# ```python
# soundtrack_dic.keys() # Las llaves son "The Bodyguard" y "Saturday Night Fever"
#
# ```
#
# </details>

# %% [markdown]
# b) En el diccionario <code>soundtrack_dic</code>, ¿cuáles son los valores (values)?

# %%
soundtrack_dic = {"The Bodyguard":"1992", "Saturday Night Fever":"1977"}
valores = soundtrack_dic.values()
print("Los valores (values) son:", valores)
# Out:
# Los valores (values) son: dict_values(['1992', '1977'])

# %% [markdown]
# <details><summary>Haz clic aquí para ver la solución</summary>
#
# ```python
# soundtrack_dic.values() # Los valores son "1992" y "1977"
#
# ```
#
# </details>

# %% [markdown]
# <hr>

# %% [markdown]
# <b>Necesitarás este diccionario para las siguientes preguntas:</b>

# %% [markdown]
# Los álbumes <b>Back in Black</b>, <b>The Bodyguard</b> y <b>Thriller</b> tienen las siguientes ventas de grabaciones musicales en millones: 50, 50 y 65 respectivamente:

# %% [markdown]
# a) Crea un diccionario llamado <code>album_sales_dict</code> donde las llaves sean el nombre del álbum y las ventas en millones sean los valores.

# %%
album_sales_dict = {
    "Back in Black": 50,
    "The Bodyguard": 50,
    "Thriller": 65
}
print("Diccionario creado:", album_sales_dict)
print("El tipo de dato es:", type(album_sales_dict).__name__)
# Out:
# Diccionario creado: {'Back in Black': 50, 'The Bodyguard': 50, 'Thriller': 65}
# El tipo de dato es: dict

# %% [markdown]
# <details><summary>Haz clic aquí para ver la solución</summary>
#
# ```python
# album_sales_dict = {"The Bodyguard":50, "Back in Black":50, "Thriller":65}
#
# ```
#
# </details>

# %% [markdown]
# b) Usa el diccionario para encontrar las ventas totales de <b>Thriller</b>:

# %%
ventas_thriller = album_sales_dict["Thriller"]

print("Las ventas totales de Thriller son:", ventas_thriller)
print("El tipo de dato es: int")
# Out:
# Las ventas totales de Thriller son: 65
# El tipo de dato es: int

# %% [markdown]
# <details><summary>Haz clic aquí para ver la solución</summary>
#
# ```python
# album_sales_dict["Thriller"]
#
# ```
#
# </details>

# %% [markdown]
# c) Encuentra los nombres de los álbumes desde el diccionario usando el método <code>keys()</code>:

# %%
nombres_albumes = album_sales_dict.keys()
print("Los nombres de los álbumes son:", nombres_albumes)
# Out:
# Los nombres de los álbumes son: dict_keys(['Back in Black', 'The Bodyguard', 'Thriller'])

# %% [markdown]
# <details><summary>Haz clic aquí para ver la solución</summary>
#
# ```python
# album_sales_dict.keys()
#
# ```
#
# </details>

# %% [markdown]
# d) Encuentra los valores de las ventas de grabaciones desde el diccionario usando el método <code>values</code>:

# %%
album_sales_dict.values()
# Out:
# dict_values([50, 50, 65])

# %% [markdown]
# <details><summary>Haz clic aquí para ver la solución</summary>
#
# ```python
# album_sales_dict.values()
#
# ```
#
# </details>

# %% [markdown]
# <a id="Scenario"></a>
# ## Escenario: Tienda de Inventario

# %% [markdown]
# El proyecto del escenario de la tienda de inventario utiliza un enfoque basado en diccionarios para desarrollar un sistema sólido para gestionar y realizar el seguimiento del inventario en una tienda minorista.
# <br>
# **Nota: Trabajarás con los detalles de dos productos.**

# %% [markdown]
# ## Tarea-1 Crear un diccionario vacío

# %% [markdown]
# Primero necesitas crear un diccionario vacío, donde almacenarás los detalles de los productos.

# %%
inventory = {}
print("Contenido del diccionario:", inventory)
# Out:
# Contenido del diccionario: {}

# %% [markdown]
# <details> <summary>Haz clic aquí para ver la solución</summary>
#
# ```python
#
# inventory ={}
#
# ```
#
# </details>

# %% [markdown]
# ## Tarea-2 Almacenar los detalles del primer producto en variables
# * Nombre del Producto (Product Name) = Mobile phone
# * Cantidad del Producto (Product Quantity) = 5
# * Precio del Producto (Product price) = 20000
# * Año de Lanzamiento del Producto (Product Release Year) = 2020

# %%
ProduNo1 = "Mobile Phone"
ProduNo1_quantity = 5
ProduNo1_price = 20000
ProduNo1_releaseYear= 2020

print("Producto:", ProduNo1)
# Out:
# Producto: Mobile Phone

# %% [markdown]
# <details> <summary>Haz clic aquí para ver la solución</summary>
#
# ```python
# ProductNo1 = "Mobile Phone"
# ProductNo1_quantity = 5
# ProductNo1_price = 20000
# ProductNo1_releaseYear= 2020
# ```
#
# </details>

# %% [markdown]
# ## Tarea-3 Agregar los detalles al inventario

# %%
inventory["ProduNo1"] = ProduNo1
inventory["ProduNo1_quantity"] = ProduNo1_quantity
inventory["ProduNo1_price"] = ProduNo1_price
inventory["ProduNo1_releaseYear"] = ProduNo1_releaseYear

# 4. Mostramos el resultado con la estructura limpia del taller
print("Contenido del diccionario:", inventory)
print("El tipo de dato es:", type(inventory).__name__)
# Out:
# Contenido del diccionario: {'ProductNo1': 'Mobile Phone', 'ProductNo1_quantity': 5, 'ProductNo1_price': 20000, 'ProductNo1_releaseYear': 2020, 'ProductNo2': 'Laptop', 'ProductNo2_quantity': 10, 'ProductNo2_price': 50000, 'ProductNo2_releaseYear': 2023, 'ProduNo1': 'Mobile Phone', 'ProduNo1_quantity': 5, 'ProduNo1_price': 20000, 'ProduNo1_releaseYear': 2020}
# El tipo de dato es: dict

# %% [markdown]
# <details> <summary>Haz clic aquí para ver la solución</summary>
#
# ```python
#
# inventory["ProductNo1"]= ProductNo1
# inventory["ProductNo1_quantity"]= ProductNo1_quantity
# inventory["ProductNo1_price"]= ProductNo1_price
# inventory["ProductNo1_releaseYear"]=ProductNo1_releaseYear
#
# ```
#
# </details>

# %% [markdown]
# ## Tarea-4 Almacenar los detalles del segundo producto en variables
# * Nombre del Producto = "Laptop"
# * Cantidad del Producto = 10
# * Precio del Producto = 50000
# * Año de Lanzamiento del Producto = 2023

# %%
ProduNo2 = "Laptop"
ProduNo2_quantity = 10
ProduNo2_price = 50000
ProduNo2_releaseYear = 2023

print("Producto 2 creado con éxito:", ProduNo2)
print("El tipo de dato es:", type(ProduNo2).__name__)
# Out:
# Producto 2 creado con éxito: Laptop
# El tipo de dato es: str

# %% [markdown]
# <details> <summary>Haz clic aquí para ver la solución</summary>
#
# ```python
#
# ProductNo2 = "Laptop"
# ProductNo2_quantity = 10
# ProductNo2_price = 50000
# ProductNo2_releaseYear= 2023
#
# ```
#
# </details>

# %% [markdown]
# ## Tarea-5 Agregar los detalles del artículo al inventario

# %%
inventory["ProduNo2"] = ProduNo2
inventory["ProduNo2_quantity"] = ProduNo2_quantity
inventory["ProduNo2_price"] = ProduNo2_price
inventory["ProduNo2_releaseYear"] = ProduNo2_releaseYear

# %% [markdown]
# <details> <summary>Haz clic aquí para ver la solución</summary>
#
# ```python
#
# inventory["ProductNo2"]= ProductNo2
# inventory["ProductNo2_quantity"]= ProductNo2_quantity
# inventory["ProductNo2_price"]= ProductNo2_price
# inventory["ProductNo2_releaseYear"]=ProductNo2_releaseYear
#
# ```
#
# </details>

# %% [markdown]
# ## Tarea-6 Mostrar los productos presentes en el inventario

# %% [markdown]
# Utiliza la sentencia print para mostrar los productos

# %%
print("Contenido del diccionario:", inventory)
print("El tipo de dato es:", type(inventory).__name__)
# Out:
# Contenido del diccionario: {'ProductNo1': 'Mobile Phone', 'ProductNo1_quantity': 5, 'ProductNo1_price': 20000, 'ProductNo1_releaseYear': 2020, 'ProductNo2': 'Laptop', 'ProductNo2_quantity': 10, 'ProductNo2_price': 50000, 'ProductNo2_releaseYear': 2023}
# El tipo de dato es: dict

# %% [markdown]
# <details> <summary>Haz clic aquí para ver la solución</summary>
#
# ```python
#
# print(inventory)
#
# ```
#
# </details>

# %% [markdown]
# ## Tarea-7 Comprobar si `ProductNo1_releaseYear` y `ProductNo2_releaseYear` están en el inventario

# %%
# Tarea-7: Comprobar de forma directa si están en el inventario
print("¿Está el año del producto 1?:", "ProduNo1_releaseYear" in inventory)
print("¿Está el año del producto 2?:", "ProduNo2_releaseYear" in inventory)
# Out:
# ¿Está el año del producto 1?: True
# ¿Está el año del producto 2?: True

# %% [markdown]
# <details> <summary>Haz clic aquí para ver la solución</summary>
#
# ```python
#
# "ProductNo1_releaseYear" in inventory
# "ProductNo2_releaseYear" in inventory
#
# ```
#
# </details>

# %% [markdown]
# **Dado que en el inventario el año de lanzamiento (`Release year`) no es requerido, eliminémoslo.**

# %% [markdown]
# ## Tarea-8 Eliminar el año de lanzamiento de ambos productos del inventario

# %%
del inventory["ProduNo1_releaseYear"]
del inventory["ProduNo2_releaseYear"]

print("Inventario final actualizado:", inventory)
# Out:
# Inventario final actualizado: {'ProductNo1': 'Mobile Phone', 'ProductNo1_quantity': 5, 'ProductNo1_price': 20000, 'ProductNo2': 'Laptop', 'ProductNo2_quantity': 10, 'ProductNo2_price': 50000, 'ProduNo1': 'Mobile Phone', 'ProduNo1_quantity': 5, 'ProduNo1_price': 20000, 'ProduNo2': 'Laptop', 'ProduNo2_quantity': 10, 'ProduNo2_price': 50000}

# %% [markdown]
# <details> <summary>Haz clic aquí para ver la solución</summary>
#
# ```python
#
# del(inventory["ProductNo1_releaseYear"])
# del(inventory["ProductNo2_releaseYear"])
#
# ```
#
# </details>
